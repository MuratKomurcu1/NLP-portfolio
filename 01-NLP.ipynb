# %% [markdown]
# 1-Tokenization → Metni kelimelere veya cümlelere ayırma

# %%
import nltk
from nltk.tokenize import word_tokenize
import string

#ilk olarak punkt yazdığımda hata aldım . Sonrasında araştırdığımda colab tabanlı olduğu için punk_tab yazmak gerekiyormuş
#geri punk olarak düzettiğimde sorun gitti
#punkt = manuel açıklama olmadan kısaltmaları, baş harfleri ve cümle sınırlarını otomatik olarak tanır
nltk.download('punkt')
#text tanımladık
text = " On January 3rd, 2023, Dr. Emily Watson, a senior data scientist at GreenAI Inc., gave a keynote speech at the International Conference on Artificial Intelligence in Paris, France. During her talk, she emphasized the importance of ethical AI and data privacy, citing recent cases of misuse in various industries. She mentioned that over 3.2 million users were affected by a data breach last year, resulting in damages estimated at $12.5 million. Furthermore, she highlighted the role of open-source libraries, such as spaCy and NLTK, in democratizing access to natural language processing tools. According to her, students and researchers can now build high-quality NLP models without needing large financial resources. AI is not just about machines, she said,it’s about how we interact with technology in a human-centered way. After the session, attendees from universities like Stanford, MIT, and Oxford approached her to discuss future collaboration opportunities. At 5:45 PM, she posted a summary of her speech on Twitter, receiving over 8,000 likes and 1,200 retweets within a few hours. Her tweet included hashtags like #AIethics, #DataPrivacy, and #NLPtools. The event concluded with a panel discussion moderated by Mr. John Lee, a journalist from TechWorld Weekly, who asked, “How can governments regulate AI without stifling innovation?” "

tokens = word_tokenize(text)
print(tokens)
# Out:
# ['On', 'January', '3rd', ',', '2023', ',', 'Dr.', 'Emily', 'Watson', ',', 'a', 'senior', 'data', 'scientist', 'at', 'GreenAI', 'Inc.', ',', 'gave', 'a', 'keynote', 'speech', 'at', 'the', 'International', 'Conference', 'on', 'Artificial', 'Intelligence', 'in', 'Paris', ',', 'France', '.', 'During', 'her', 'talk', ',', 'she', 'emphasized', 'the', 'importance', 'of', 'ethical', 'AI', 'and', 'data', 'privacy', ',', 'citing', 'recent', 'cases', 'of', 'misuse', 'in', 'various', 'industries', '.', 'She', 'mentioned', 'that', 'over', '3.2', 'million', 'users', 'were', 'affected', 'by', 'a', 'data', 'breach', 'last', 'year', ',', 'resulting', 'in', 'damages', 'estimated', 'at', '$', '12.5', 'million', '.', 'Furthermore', ',', 'she', 'highlighted', 'the', 'role', 'of', 'open-source', 'libraries', ',', 'such', 'as', 'spaCy', 'and', 'NLTK', ',', 'in', 'democratizing', 'access', 'to', 'natural', 'language', 'processing', 'tools', '.', 'According', 'to', 'her', ',', 'students', 'and', 'researchers
# ...

# %% [markdown]
# *2*-Lowercasing → Tüm kelimeleri küçük harfe çevirme

# %%
lower_text = text.lower()
print(lower_text)
# Out:
#  on january 3rd, 2023, dr. emily watson, a senior data scientist at greenai inc., gave a keynote speech at the international conference on artificial intelligence in paris, france. during her talk, she emphasized the importance of ethical ai and data privacy, citing recent cases of misuse in various industries. she mentioned that over 3.2 million users were affected by a data breach last year, resulting in damages estimated at $12.5 million. furthermore, she highlighted the role of open-source libraries, such as spacy and nltk, in democratizing access to natural language processing tools. according to her, students and researchers can now build high-quality nlp models without needing large financial resources. ai is not just about machines, she said,it’s about how we interact with technology in a human-centered way. after the session, attendees from universities like stanford, mit, and oxford approached her to discuss future collaboration opportunities. at 5:45 pm, she posted a summa
# ...

# %% [markdown]
# 3-Removing Punctuation → Noktalama işaretlerini kaldırma

# %%
clean_text = ''.join([char for char in text if char not in string.punctuation])
print(clean_text)
# Out:
#  On January 3rd 2023 Dr Emily Watson a senior data scientist at GreenAI Inc gave a keynote speech at the International Conference on Artificial Intelligence in Paris France During her talk she emphasized the importance of ethical AI and data privacy citing recent cases of misuse in various industries She mentioned that over 32 million users were affected by a data breach last year resulting in damages estimated at 125 million Furthermore she highlighted the role of opensource libraries such as spaCy and NLTK in democratizing access to natural language processing tools According to her students and researchers can now build highquality NLP models without needing large financial resources AI is not just about machines she saidit’s about how we interact with technology in a humancentered way After the session attendees from universities like Stanford MIT and Oxford approached her to discuss future collaboration opportunities At 545 PM she posted a summary of her speech on Twitter receiv
# ...

# %% [markdown]
# 4-Removing Stopwords → “the”, “is”, “on” gibi anlamsız kelimeleri çıkarma

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
sw = set(stopwords.words('english'))
sw
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
# ...

# %% [markdown]
# 5-Removing Numbers → Sayıları temizleme (örn. 3.2, 12.5, 2023)

# %%
import re

cl = re.sub(r'\d+(\.\d+)?', '', text)
cl
# Out:
# ' On January rd, , Dr. Emily Watson, a senior data scientist at GreenAI Inc., gave a keynote speech at the International Conference on Artificial Intelligence in Paris, France. During her talk, she emphasized the importance of ethical AI and data privacy, citing recent cases of misuse in various industries. She mentioned that over  million users were affected by a data breach last year, resulting in damages estimated at $ million. Furthermore, she highlighted the role of open-source libraries, such as spaCy and NLTK, in democratizing access to natural language processing tools. According to her, students and researchers can now build high-quality NLP models without needing large financial resources. AI is not just about machines, she said,it’s about how we interact with technology in a human-centered way. After the session, attendees from universities like Stanford, MIT, and Oxford approached her to discuss future collaboration opportunities. At : PM, she posted a summary of her spee
# ...

# %% [markdown]
# 6-Stemming or Lemmatization → Kelimeleri kök ya da gövdelerine indirgeme

# %%
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
stm = PorterStemmer()
lemmatizer = WordNetLemmatizer()

stemming_words = [stm.stem(word) for word in text]
lemmatization_words = [lemmatizer.lemmatize(word, pos='v') for word in text] # fiil olduğu için pos içine "v" yazdık

print("Stemming:", stemming_words)
print("Lemmatization:", lemmatization_words)
# Out:
# Stemming: [' ', 'o', 'n', ' ', 'j', 'a', 'n', 'u', 'a', 'r', 'y', ' ', '3', 'r', 'd', ',', ' ', '2', '0', '2', '3', ',', ' ', 'd', 'r', '.', ' ', 'e', 'm', 'i', 'l', 'y', ' ', 'w', 'a', 't', 's', 'o', 'n', ',', ' ', 'a', ' ', 's', 'e', 'n', 'i', 'o', 'r', ' ', 'd', 'a', 't', 'a', ' ', 's', 'c', 'i', 'e', 'n', 't', 'i', 's', 't', ' ', 'a', 't', ' ', 'g', 'r', 'e', 'e', 'n', 'a', 'i', ' ', 'i', 'n', 'c', '.', ',', ' ', 'g', 'a', 'v', 'e', ' ', 'a', ' ', 'k', 'e', 'y', 'n', 'o', 't', 'e', ' ', 's', 'p', 'e', 'e', 'c', 'h', ' ', 'a', 't', ' ', 't', 'h', 'e', ' ', 'i', 'n', 't', 'e', 'r', 'n', 'a', 't', 'i', 'o', 'n', 'a', 'l', ' ', 'c', 'o', 'n', 'f', 'e', 'r', 'e', 'n', 'c', 'e', ' ', 'o', 'n', ' ', 'a', 'r', 't', 'i', 'f', 'i', 'c', 'i', 'a', 'l', ' ', 'i', 'n', 't', 'e', 'l', 'l', 'i', 'g', 'e', 'n', 'c', 'e', ' ', 'i', 'n', ' ', 'p', 'a', 'r', 'i', 's', ',', ' ', 'f', 'r', 'a', 'n', 'c', 'e', '.', ' ', 'd', 'u', 'r', 'i', 'n', 'g', ' ', 'h', 'e', 'r', ' ', 't', 'a', 'l', 'k', ',', ' 
# ...

# %% [markdown]
# 7-Named Entity Recognition (NER) → Kişi adları, yer adları, kurumlar vb. tespiti

# %%
#Ön Hazırlık:

# !pip install spacy
# !python -m spacy download en_core_web_sm

import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp(text)

for ent in doc.ents:
    print(ent.text, "→", ent.label_)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 22.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# January 3rd, 2023 → DATE
# Emily Watson → PERSON
# GreenAI Inc. → ORG
# the International Conference on Artificial Intelligence → ORG
# Paris → GPE
# France → GPE
# over 3.2 million → CARDINAL
# last year → DATE
# $12.5 million → MONEY
# NLTK → ORG
# NLP → ORG
# Stanford → ORG
# MIT → ORG
# Oxford → ORG
# 5:45 PM → TIME
# Twitter → PERSON
# 8,000 → CARDINAL
# 1,200 → CARDINAL
# a few hours → TIME
# DataPrivacy → MONEY
# NLPtools → PERSON
# John Lee → PERSON
# TechWorld Weekly → ORG
# AI → GPE

# %% [markdown]
# 8-Part-of-Speech (POS) Tagging → Her kelimenin türünü belirleme (isim, fiil, sıfat...)

# %%
from nltk import pos_tag

nltk.download('averaged_perceptron_tagger_eng')

tagged = pos_tag(tokens)

print(tagged)

# %% [markdown]
# 9-Word Frequency Count → En sık geçen kelimeleri görme

# %%
from collections import Counter

word_freq = Counter(tokens)
print(word_freq)
# Out:
# Counter({',': 24, '.': 9, 'a': 8, 'and': 6, 'in': 5, 'the': 4, 'her': 4, 'she': 4, 'of': 4, 'data': 3, 'at': 3, 'AI': 3, 'to': 3, '#': 3, 'speech': 2, 'on': 2, 'over': 2, 'million': 2, 'by': 2, 'can': 2, 'without': 2, 'about': 2, 'with': 2, 'from': 2, 'like': 2, 'On': 1, 'January': 1, '3rd': 1, '2023': 1, 'Dr.': 1, 'Emily': 1, 'Watson': 1, 'senior': 1, 'scientist': 1, 'GreenAI': 1, 'Inc.': 1, 'gave': 1, 'keynote': 1, 'International': 1, 'Conference': 1, 'Artificial': 1, 'Intelligence': 1, 'Paris': 1, 'France': 1, 'During': 1, 'talk': 1, 'emphasized': 1, 'importance': 1, 'ethical': 1, 'privacy': 1, 'citing': 1, 'recent': 1, 'cases': 1, 'misuse': 1, 'various': 1, 'industries': 1, 'She': 1, 'mentioned': 1, 'that': 1, '3.2': 1, 'users': 1, 'were': 1, 'affected': 1, 'breach': 1, 'last': 1, 'year': 1, 'resulting': 1, 'damages': 1, 'estimated': 1, '$': 1, '12.5': 1, 'Furthermore': 1, 'highlighted': 1, 'role': 1, 'open-source': 1, 'libraries': 1, 'such': 1, 'as': 1, 'spaCy': 1, 'NLTK': 1, 'd
# ...

# %% [markdown]
# 10-Text Visualization → Word cloud, bar chart vb. görselleştirme

# %%
#World cloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud - En Sık Geçen Kelimeler")
plt.show()

# %%
#Bar Chart (ilk 10 kelime)

most_common_words = word_freq.most_common(10)
words, counts = zip(*most_common_words)

plt.figure(figsize=(10, 6))
plt.bar(words, counts)
plt.xlabel("Kelime")
plt.ylabel("Frekans")
plt.title("En Sık Geçen 10 Kelime (Bar Chart)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
